# %% [markdown]
# # MNIST 데이터셋 학습 (to do)
# MNIST 데이터셋은0~9까지 총 10개의 label로 이루어진 이미지 분류를 위한 사이즈의 손글씨 데이터셋이다.
# 각각의 레이블마다 28×28 크기 이미지인 60,000개의 training 데이터셋, 10,000개의 test 데이터셋이 존재하고, 결과적으로 총 70,000개의 28×28 크기의 이미지로 데이터셋이 구성되어 있다.

# %%
import tensorflow.keras.utils as utils
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras import backend

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## (1) 데이터셋

# %%
(X_train, Y_train),(X_test, Y_test) = datasets.mnist.load_data()
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

Y_train = utils.to_categorical(Y_train)
Y_test = utils.to_categorical(Y_test)

print(X_train.shape, Y_train.shape)

n_in = X_train.shape[1:]
n_out = Y_train.shape[-1]
# Out:
# (60000, 28, 28, 1) (60000, 10)

# %% [markdown]
# ## (2) 모델링

# %%
from tensorflow.keras.layers import Flatten, BatchNormalization, Dropout, ReLU
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D

# %%
def CNN(n_in, n_out):
    model = Sequential()
    model.add(Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu', input_shape=n_in))
    model.add(Conv2D(32, (3, 3), padding='same',strides=(2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(n_out, activation='softmax'))
    return model

def CNN_BN(n_in, n_out):
    model = Sequential()
    model.add(Conv2D(16, kernel_size=(3, 3), padding='same', input_shape=n_in))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(32, (3, 3), padding='same',strides=(2, 2)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Dense(n_out, activation='softmax'))
    return model

# %%
model=CNN_BN(n_in, n_out)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               401664
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 410,250
# Trainable params: 409,642
# Non-trainable params: 608
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
# %matplotlib inline

plot_model(model, show_shapes=True)

# %% [markdown]
# ## (3) 모델의 학습과정 설정

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, decay=1e-5, epsilon=None, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# ## (4) 모델 학습시키기

# %%
earlystopper = EarlyStopping(monitor='val_accuracy', patience=30, verbose=0, mode='auto')
history = model.fit(X_train, Y_train, batch_size=256, epochs=100, validation_split=0.2, callbacks = [earlystopper])
# Out:
# Epoch 1/100
# 188/188 [==============================] - 3s 14ms/step - loss: 9.8114e-05 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9904
# Epoch 2/100
# 188/188 [==============================] - 3s 13ms/step - loss: 5.4614e-05 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9912
# Epoch 3/100
# 188/188 [==============================] - 3s 14ms/step - loss: 5.7843e-05 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9911
# Epoch 4/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.4215e-04 - accuracy: 0.9999 - val_loss: 0.0627 - val_accuracy: 0.9908
# Epoch 5/100
# 188/188 [==============================] - 2s 13ms/step - loss: 2.4984e-04 - accuracy: 0.9999 - val_loss: 0.0561 - val_accuracy: 0.9905
# Epoch 6/100
# 188/188 [==============================] - 2s 13ms/step - loss: 9.2541e-05 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9908
# Epoch 7/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.5733e-04 - accuracy: 0.9999 - val_loss: 0.0599 - val_accuracy: 0.9906
# Epoch 8/100
# 188/188 [==============================] - 2s 13ms/step - loss: 2.2515e-04 - accuracy: 0.9999 - val_loss: 0.0582 - val_accuracy: 0.9906
# Epoch 9/100
# 188/188 [==============================] - 3s 13ms/step - loss: 3.7562e-04 - accuracy: 0.9998 - val_loss: 0.0594 - val_accuracy: 0.9913
# Epoch 10/100
# 188/188 [==============================] - 2s 13ms/step - loss: 1.7146e-04 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9910
# Epoch 11/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.4769e-04 - accuracy: 0.9999 - val_loss: 0.0592 - val_accuracy: 0.9909
# Epoch 12/100
# 188/188 [==============================] - 2s 13ms/step - loss: 4.9188e-04 - accuracy: 0.9999 - val_loss: 0.0601 - val_accuracy: 0.9905
# Epoch 13/100
# 188/188 [==============================] - 2s 13ms/step - loss: 2.4146e-04 - accuracy: 0.9999 - val_loss: 0.0572 - val_accuracy: 0.9913
# Epoch 14/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.6688e-04 - accuracy: 0.9999 - val_loss: 0.0587 - val_accuracy: 0.9912
# Epoch 15/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.6888e-04 - accuracy: 0.9999 - val_loss: 0.0645 - val_accuracy: 0.9909
# Epoch 16/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.7055e-04 - accuracy: 0.9999 - val_loss: 0.0579 - val_accuracy: 0.9905
# Epoch 17/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.6214e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9906
# Epoch 18/100
# 188/188 [==============================] - 2s 13ms/step - loss: 2.0763e-04 - accuracy: 0.9999 - val_loss: 0.0860 - val_accuracy: 0.9892
# Epoch 19/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.4316e-04 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9906
# Epoch 20/100
# 188/188 [==============================] - 3s 13ms/step - loss: 6.3430e-05 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9908
# Epoch 21/100
# 188/188 [==============================] - 3s 13ms/step - loss: 9.0691e-05 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9909
# Epoch 22/100
# 188/188 [==============================] - 3s 13ms/step - loss: 7.9358e-05 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9905
# Epoch 23/100
# 188/188 [==============================] - 3s 14ms/step - loss: 4.1872e-04 - accuracy: 0.9998 - val_loss: 0.0628 - val_accuracy: 0.9902
# Epoch 24/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.6829e-04 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9908
# Epoch 25/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.1329e-04 - accuracy: 1.0000 - val_loss: 0.0565 - val_accuracy: 0.9910
# Epoch 26/100
# 188/188 [==============================] - 3s 13ms/step - loss: 4.0696e-04 - accuracy: 0.9999 - val_loss: 0.0562 - val_accuracy: 0.9912
# Epoch 27/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.3586e-04 - accuracy: 0.9999 - val_loss: 0.0578 - val_accuracy: 0.9916
# Epoch 28/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.3896e-04 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9912
# Epoch 29/100
# 188/188 [==============================] - 2s 13ms/step - loss: 2.3381e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9906
# Epoch 30/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.6493e-04 - accuracy: 0.9999 - val_loss: 0.0577 - val_accuracy: 0.9908
# Epoch 31/100
# 188/188 [==============================] - 3s 13ms/step - loss: 6.0399e-05 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9904
# Epoch 32/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.4480e-04 - accuracy: 0.9999 - val_loss: 0.0616 - val_accuracy: 0.9908
# Epoch 33/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.9287e-04 - accuracy: 0.9999 - val_loss: 0.0604 - val_accuracy: 0.9904
# Epoch 34/100
# 188/188 [==============================] - 2s 13ms/step - loss: 1.7794e-04 - accuracy: 0.9999 - val_loss: 0.0627 - val_accuracy: 0.9901
# Epoch 35/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.3552e-04 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9910
# Epoch 36/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.5522e-04 - accuracy: 0.9999 - val_loss: 0.0556 - val_accuracy: 0.9913
# Epoch 37/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.0617e-04 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9918
# Epoch 38/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.3953e-04 - accuracy: 0.9999 - val_loss: 0.0580 - val_accuracy: 0.9908
# Epoch 39/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.0148e-04 - accuracy: 0.9999 - val_loss: 0.0586 - val_accuracy: 0.9914
# Epoch 40/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.6769e-04 - accuracy: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9913
# Epoch 41/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.7041e-04 - accuracy: 0.9999 - val_loss: 0.0576 - val_accuracy: 0.9918
# Epoch 42/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.2622e-04 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9916
# Epoch 43/100
# 188/188 [==============================] - 3s 13ms/step - loss: 6.9706e-05 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9923
# Epoch 44/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.7848e-04 - accuracy: 0.9999 - val_loss: 0.0608 - val_accuracy: 0.9917
# Epoch 45/100
# 188/188 [==============================] - 3s 14ms/step - loss: 6.5833e-05 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9912
# Epoch 46/100
# 188/188 [==============================] - 2s 13ms/step - loss: 1.6916e-04 - accuracy: 0.9999 - val_loss: 0.0584 - val_accuracy: 0.9916
# Epoch 47/100
# 188/188 [==============================] - 3s 13ms/step - loss: 9.5107e-05 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9908
# Epoch 48/100
# 188/188 [==============================] - 2s 13ms/step - loss: 3.2156e-04 - accuracy: 0.9999 - val_loss: 0.0545 - val_accuracy: 0.9908
# Epoch 49/100
# 188/188 [==============================] - 3s 14ms/step - loss: 3.3479e-04 - accuracy: 0.9999 - val_loss: 0.0555 - val_accuracy: 0.9916
# Epoch 50/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.1512e-04 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9908
# Epoch 51/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.0605e-04 - accuracy: 0.9999 - val_loss: 0.0572 - val_accuracy: 0.9912
# Epoch 52/100
# 188/188 [==============================] - 3s 14ms/step - loss: 7.9586e-05 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9918
# Epoch 53/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.7154e-04 - accuracy: 0.9999 - val_loss: 0.0584 - val_accuracy: 0.9911
# Epoch 54/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.0957e-04 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9921
# Epoch 55/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.2073e-04 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9922
# Epoch 56/100
# 188/188 [==============================] - 3s 13ms/step - loss: 3.4342e-05 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9918
# Epoch 57/100
# 188/188 [==============================] - 3s 13ms/step - loss: 9.4888e-05 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9918
# Epoch 58/100
# 188/188 [==============================] - 3s 14ms/step - loss: 1.8405e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9911
# Epoch 59/100
# 188/188 [==============================] - 3s 13ms/step - loss: 9.8627e-05 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9912
# Epoch 60/100
# 188/188 [==============================] - 3s 14ms/step - loss: 9.1562e-05 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9910
# Epoch 61/100
# 188/188 [==============================] - 3s 14ms/step - loss: 8.9528e-05 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9912
# Epoch 62/100
# 188/188 [==============================] - 3s 14ms/step - loss: 1.1952e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9912
# Epoch 63/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.1006e-04 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9912
# Epoch 64/100
# 188/188 [==============================] - 3s 13ms/step - loss: 8.8316e-05 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9913
# Epoch 65/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.1082e-04 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9907
# Epoch 66/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.3001e-04 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9916
# Epoch 67/100
# 188/188 [==============================] - 3s 13ms/step - loss: 1.2159e-04 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9912
# Epoch 68/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.5127e-04 - accuracy: 0.9999 - val_loss: 0.0584 - val_accuracy: 0.9920
# Epoch 69/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.3183e-04 - accuracy: 0.9999 - val_loss: 0.0592 - val_accuracy: 0.9918
# Epoch 70/100
# 188/188 [==============================] - 3s 14ms/step - loss: 6.7650e-05 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9915
# Epoch 71/100
# 188/188 [==============================] - 3s 14ms/step - loss: 2.3737e-04 - accuracy: 0.9999 - val_loss: 0.0567 - val_accuracy: 0.9912
# Epoch 72/100
# 188/188 [==============================] - 3s 13ms/step - loss: 2.1725e-04 - accuracy: 0.9999 - val_loss: 0.0556 - val_accuracy: 0.9918
# Epoch 73/100
# 188/188 [==============================] - 3s 14ms/step - loss: 1.2494e-04 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9914

# %% [markdown]
# ## (5) 모델 평가하기

# %%
loss_and_accuracy = model.evaluate(X_test, Y_test, batch_size=256)
print('loss : %.4f, accruracy : %.4f'%(loss_and_accuracy[0],loss_and_accuracy[1]))
# Out:
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9915
# loss : 0.0533, accruracy : 0.9915

# %% [markdown]
# ## (6) 모델 사용하기
#
# 모델 평가 후, 분류 오류가 난 사례들을 확인해보고, 모델과 데이터셋에 대한 평가 및 분석해볼 것

# %%
test_data = X_test[-1].reshape(1,28,28,1)
pred_y = model.predict(test_data).argmax()
real_y = Y_test[-1].argmax()
print('predict label : {}, real label : {}'.format(pred_y, real_y))
plt.imshow(X_test[-1].reshape(28,28), cmap='gray')
# Out:
# predict label : 6, real label : 6
